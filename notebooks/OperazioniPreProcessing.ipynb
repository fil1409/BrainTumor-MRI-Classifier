# %%
import os
import imagehash
from PIL import Image

# Funzione per calcolare l'hash di tutte le immagini in una directory con sottocartelle
def calcola_hash(base_directory):
    hashes = {}
    for root, _, files in os.walk(base_directory):
        for filename in files:
            if filename.endswith((".png", ".jpg", ".jpeg")):
                image_path = os.path.join(root, filename)
                image = Image.open(image_path)
                image_hash = imagehash.phash(image)
                relative_path = os.path.relpath(image_path, base_directory)
                hashes[relative_path] = image_hash
    return hashes

# Percorsi dei dataset
dataset1_path = r""
dataset2_path = r""

# Calcolare gli hash per i due dataset
hashes_dataset1 = calcola_hash(dataset1_path)
hashes_dataset2 = calcola_hash(dataset2_path)

# Confrontare gli hash
immagini_comuni = []
for file1, hash1 in hashes_dataset1.items():
    for file2, hash2 in hashes_dataset2.items():
        if hash1 == hash2:
            immagini_comuni.append((file1, file2))

# Stampa le immagini comuni
print("Immagini comuni nei due dataset:")
for img1, img2 in immagini_comuni:
    print(f"{img1} in dataset1 e {img2} in dataset2")
# Out:
# Immagini comuni nei due dataset:
# glioma_tumor\Te-gl_0014.jpg in dataset1 e glioma_tumor\image(66).jpg in dataset2
# glioma_tumor\Te-gl_0066.jpg in dataset1 e glioma_tumor\image(72).jpg in dataset2
# glioma_tumor\Te-gl_0068.jpg in dataset1 e glioma_tumor\image(73).jpg in dataset2
# meningioma_tumor\Te-meTr_0000.jpg in dataset1 e meningioma_tumor\image(1).jpg in dataset2
# meningioma_tumor\Te-meTr_0001.jpg in dataset1 e meningioma_tumor\image(10).jpg in dataset2
# meningioma_tumor\Te-meTr_0002.jpg in dataset1 e meningioma_tumor\image(100).jpg in dataset2
# meningioma_tumor\Te-meTr_0003.jpg in dataset1 e meningioma_tumor\image(102).jpg in dataset2
# meningioma_tumor\Te-meTr_0004.jpg in dataset1 e meningioma_tumor\image(106).jpg in dataset2
# meningioma_tumor\Te-meTr_0004.jpg in dataset1 e meningioma_tumor\image(126).jpg in dataset2
# meningioma_tumor\Te-meTr_0005.jpg in dataset1 e meningioma_tumor\image(107).jpg in dataset2
# meningioma_tumor\Te-meTr_0006.jpg in dataset1 e meningioma_tumor\image(109).jpg in dataset2
# meningioma_tumor\Te-meTr_0007.jpg in dataset1 e meningioma_tumor\image(11).jpg in dataset2
# meningioma_tumor\Te-meTr_0008.jpg in dataset1 e meningioma_tumor\image(112).jpg in dataset2
# meningioma_tumor\Te-meTr_0009.jpg in dataset1 e meningioma_tumor\image(113).jpg in dataset2
# meningioma_tumor\Te-me_0010.jpg in dataset1 e meningioma_tumor\image(118).jpg in dataset2
# meningioma_tumor\Te-me_0010.jpg in dataset1 e meningioma_tumor\image(24).jpg in dataset2
# meningioma_tumor\Te-me_0011.jpg in dataset1 e meningioma_tumor\image(12).jpg in dataset2
# meningioma_tumor\Te-me_0012.jpg in dataset1 e meningioma_tumor\image(120).jpg in dataset2
# meningioma_tumor\Te-me_0013.jpg in dataset1 e meningioma_tumor\image(121).jpg in dataset2
# meningioma_tumor\Te-me_0013.jpg in dataset1 e meningioma_tumor\image(83).jpg in dataset2
# meningioma_tumor\Te-me_0014.jpg in dataset1 e meningioma_tumor\image(123).jpg in dataset2
# meningioma_tumor\Te-me_0096.jpg in dataset1 e meningioma_tumor\image(121).jpg in dataset2
# meningioma_tumor\Te-me_0096.jpg in dataset1 e meningioma_tumor\image(83).jpg in dataset2
# meningioma_tumor\Te-me_0097.jpg in dataset1 e meningioma_tumor\image(84).jpg in dataset2
# meningioma_tumor\Te-me_0098.jpg in dataset1 e meningioma_tumor\image(85).jpg in dataset2
# meningioma_tumor\Te-me_0099.jpg in dataset1 e meningioma_tumor\image(86).jpg in dataset2
# meningioma_tumor\Te-me_0100.jpg in dataset1 e meningioma_tumor\image(87).jpg in dataset2
# meningioma_tumor\Te-me_0101.jpg in dataset1 e meningioma_tumor\image(88).jpg in dataset2
# meningioma_tumor\Te-me_0102.jpg in dataset1 e meningioma_tumor\image(89).jpg in dataset2
# meningioma_tumor\Te-me_0103.jpg in dataset1 e meningioma_tumor\image(9).jpg in dataset2
# meningioma_tumor\Te-me_0104.jpg in dataset1 e meningioma_tumor\image(19).jpg in dataset2
# meningioma_tumor\Te-me_0104.jpg in dataset1 e meningioma_tumor\image(90).jpg in dataset2
# meningioma_tumor\Te-me_0105.jpg in dataset1 e meningioma_tumor\image(91).jpg in dataset2
# meningioma_tumor\Te-me_0106.jpg in dataset1 e meningioma_tumor\image(92).jpg in dataset2
# meningioma_tumor\Te-me_0107.jpg in dataset1 e meningioma_tumor\image(93).jpg in dataset2
# meningioma_tumor\Te-me_0108.jpg in dataset1 e meningioma_tumor\image(94).jpg in dataset2
# meningioma_tumor\Te-me_0109.jpg in dataset1 e meningioma_tumor\image(95).jpg in dataset2
# meningioma_tumor\Te-me_0110.jpg in dataset1 e meningioma_tumor\image(96).jpg in dataset2
# meningioma_tumor\Te-me_0111.jpg in dataset1 e meningioma_tumor\image(97).jpg in dataset2
# meningioma_tumor\Te-me_0112.jpg in dataset1 e meningioma_tumor\image(98).jpg in dataset2
# meningioma_tumor\Te-me_0113.jpg in dataset1 e meningioma_tumor\image(99).jpg in dataset2
# meningioma_tumor\Te-me_0114.jpg in dataset1 e meningioma_tumor\image.jpg in dataset2
# meningioma_tumor\Te-me_0140.jpg in dataset1 e meningioma_tumor\image(100).jpg in dataset2
# meningioma_tumor\Te-me_0143.jpg in dataset1 e meningioma_tumor\image(92).jpg in dataset2
# meningioma_tumor\Te-me_0145.jpg in dataset1 e meningioma_tumor\image(96).jpg in dataset2
# no_tumor\Te-noTr_0000.jpg in dataset1 e no_tumor\image(1).jpg in dataset2
# no_tumor\Te-noTr_0001.jpg in dataset1 e no_tumor\image(10).jpg in dataset2
# no_tumor\Te-noTr_0001.jpg in dataset1 e no_tumor\image(33).jpg in dataset2
# no_tumor\Te-noTr_0001.jpg in dataset1 e no_tumor\image(66).jpg in dataset2
# no_tumor\Te-noTr_0001.jpg in dataset1 e no_tumor\image(81).jpg in dataset2
# no_tumor\Te-noTr_0002.jpg in dataset1 e no_tumor\image(100).jpg in dataset2
# no_tumor\Te-noTr_0003.jpg in dataset1 e no_tumor\image(101).jpg in dataset2
# no_tumor\Te-noTr_0004.jpg in dataset1 e no_tumor\image(102).jpg in dataset2
# no_tumor\Te-noTr_0005.jpg in dataset1 e no_tumor\image(103).jpg in dataset2
# no_tumor\Te-noTr_0006.jpg in dataset1 e no_tumor\image(104).jpg in dataset2
# no_tumor\Te-noTr_0007.jpg in dataset1 e no_tumor\image(11).jpg in dataset2
# no_tumor\Te-noTr_0007.jpg in dataset1 e no_tumor\image(85).jpg in dataset2
# no_tumor\Te-noTr_0008.jpg in dataset1 e no_tumor\image(12).jpg in dataset2
# no_tumor\Te-noTr_0009.jpg in dataset1 e no_tumor\image(13).jpg in dataset2
# no_tumor\Te-no_0010.jpg in dataset1 e no_tumor\image(14).jpg in dataset2
# no_tumor\Te-no_0011.jpg in dataset1 e no_tumor\image(15).jpg in dataset2
# no_tumor\Te-no_0011.jpg in dataset1 e no_tumor\image(49).jpg in dataset2
# no_tumor\Te-no_0011.jpg in dataset1 e no_tumor\image(53).jpg in dataset2
# no_tumor\Te-no_0011.jpg in dataset1 e no_tumor\image(67).jpg in dataset2
# no_tumor\Te-no_0011.jpg in dataset1 e no_tumor\image(84).jpg in dataset2
# no_tumor\Te-no_0012.jpg in dataset1 e no_tumor\image(16).jpg in dataset2
# no_tumor\Te-no_0012.jpg in dataset1 e no_tumor\image(45).jpg in dataset2
# no_tumor\Te-no_0012.jpg in dataset1 e no_tumor\image(55).jpg in dataset2
# no_tumor\Te-no_0012.jpg in dataset1 e no_tumor\image(60).jpg in dataset2
# no_tumor\Te-no_0013.jpg in dataset1 e no_tumor\image(17).jpg in dataset2
# no_tumor\Te-no_0014.jpg in dataset1 e no_tumor\image(18).jpg in dataset2
# no_tumor\Te-no_0015.jpg in dataset1 e no_tumor\image(19).jpg in dataset2
# no_tumor\Te-no_0016.jpg in dataset1 e no_tumor\image(2).jpg in dataset2
# no_tumor\Te-no_0017.jpg in dataset1 e no_tumor\image(20).jpg in dataset2
# no_tumor\Te-no_0018.jpg in dataset1 e no_tumor\image(21).jpg in dataset2
# no_tumor\Te-no_0018.jpg in dataset1 e no_tumor\image(69).jpg in dataset2
# no_tumor\Te-no_0019.jpg in dataset1 e no_tumor\image(22).jpg in dataset2
# no_tumor\Te-no_0019.jpg in dataset1 e no_tumor\image(61).jpg in dataset2
# no_tumor\Te-no_0019.jpg in dataset1 e no_tumor\image(71).jpg in dataset2
# no_tumor\Te-no_0020.jpg in dataset1 e no_tumor\image(23).jpg in dataset2
# no_tumor\Te-no_0021.jpg in dataset1 e no_tumor\image(24).jpg in dataset2
# no_tumor\Te-no_0021.jpg in dataset1 e no_tumor\image(70).jpg in dataset2
# no_tumor\Te-no_0022.jpg in dataset1 e no_tumor\image(25).jpg in dataset2
# no_tumor\Te-no_0022.jpg in dataset1 e no_tumor\image(73).jpg in dataset2
# no_tumor\Te-no_0023.jpg in dataset1 e no_tumor\image(26).jpg in dataset2
# no_tumor\Te-no_0024.jpg in dataset1 e no_tumor\image(27).jpg in dataset2
# no_tumor\Te-no_0025.jpg in dataset1 e no_tumor\image(28).jpg in dataset2
# no_tumor\Te-no_0026.jpg in dataset1 e no_tumor\image(29).jpg in dataset2
# no_tumor\Te-no_0026.jpg in dataset1 e no_tumor\image(39).jpg in dataset2
# no_tumor\Te-no_0027.jpg in dataset1 e no_tumor\image(3).jpg in dataset2
# no_tumor\Te-no_0028.jpg in dataset1 e no_tumor\image(30).jpg in dataset2
# no_tumor\Te-no_0029.jpg in dataset1 e no_tumor\image(31).jpg in dataset2
# no_tumor\Te-no_0029.jpg in dataset1 e no_tumor\image(68).jpg in dataset2
# no_tumor\Te-no_0030.jpg in dataset1 e no_tumor\image(32).jpg in dataset2
# no_tumor\Te-no_0030.jpg in dataset1 e no_tumor\image(64).jpg in dataset2
# no_tumor\Te-no_0031.jpg in dataset1 e no_tumor\image(10).jpg in dataset2
# no_tumor\Te-no_0031.jpg in dataset1 e no_tumor\image(33).jpg in dataset2
# no_tumor\Te-no_0031.jpg in dataset1 e no_tumor\image(66).jpg in dataset2
# no_tumor\Te-no_0031.jpg in dataset1 e no_tumor\image(81).jpg in dataset2
# no_tumor\Te-no_0032.jpg in dataset1 e no_tumor\image(34).jpg in dataset2
# no_tumor\Te-no_0033.jpg in dataset1 e no_tumor\image(35).jpg in dataset2
# no_tumor\Te-no_0034.jpg in dataset1 e no_tumor\image(36).jpg in dataset2
# no_tumor\Te-no_0035.jpg in dataset1 e no_tumor\image(37).jpg in dataset2
# no_tumor\Te-no_0035.jpg in dataset1 e no_tumor\image(79).jpg in dataset2
# no_tumor\Te-no_0036.jpg in dataset1 e no_tumor\image(38).jpg in dataset2
# no_tumor\Te-no_0037.jpg in dataset1 e no_tumor\image(29).jpg in dataset2
# no_tumor\Te-no_0037.jpg in dataset1 e no_tumor\image(39).jpg in dataset2
# no_tumor\Te-no_0038.jpg in dataset1 e no_tumor\image(4).jpg in dataset2
# no_tumor\Te-no_0039.jpg in dataset1 e no_tumor\image(40).jpg in dataset2
# no_tumor\Te-no_0040.jpg in dataset1 e no_tumor\image(41).jpg in dataset2
# no_tumor\Te-no_0040.jpg in dataset1 e no_tumor\image(52).jpg in dataset2
# no_tumor\Te-no_0041.jpg in dataset1 e no_tumor\image(42).jpg in dataset2
# no_tumor\Te-no_0042.jpg in dataset1 e no_tumor\image(43).jpg in dataset2
# no_tumor\Te-no_0043.jpg in dataset1 e no_tumor\image(44).jpg in dataset2
# no_tumor\Te-no_0044.jpg in dataset1 e no_tumor\image(16).jpg in dataset2
# no_tumor\Te-no_0044.jpg in dataset1 e no_tumor\image(45).jpg in dataset2
# no_tumor\Te-no_0044.jpg in dataset1 e no_tumor\image(55).jpg in dataset2
# no_tumor\Te-no_0044.jpg in dataset1 e no_tumor\image(60).jpg in dataset2
# no_tumor\Te-no_0045.jpg in dataset1 e no_tumor\image(46).jpg in dataset2
# no_tumor\Te-no_0045.jpg in dataset1 e no_tumor\image(50).jpg in dataset2
# no_tumor\Te-no_0045.jpg in dataset1 e no_tumor\image(54).jpg in dataset2
# no_tumor\Te-no_0046.jpg in dataset1 e no_tumor\image(47).jpg in dataset2
# no_tumor\Te-no_0046.jpg in dataset1 e no_tumor\image(6).jpg in dataset2
# no_tumor\Te-no_0047.jpg in dataset1 e no_tumor\image(48).jpg in dataset2
# no_tumor\Te-no_0047.jpg in dataset1 e no_tumor\image(75).jpg in dataset2
# no_tumor\Te-no_0048.jpg in dataset1 e no_tumor\image(15).jpg in dataset2
# no_tumor\Te-no_0048.jpg in dataset1 e no_tumor\image(49).jpg in dataset2
# no_tumor\Te-no_0048.jpg in dataset1 e no_tumor\image(53).jpg in dataset2
# no_tumor\Te-no_0048.jpg in dataset1 e no_tumor\image(67).jpg in dataset2
# no_tumor\Te-no_0048.jpg in dataset1 e no_tumor\image(84).jpg in dataset2
# no_tumor\Te-no_0049.jpg in dataset1 e no_tumor\image(5).jpg in dataset2
# no_tumor\Te-no_0050.jpg in dataset1 e no_tumor\image(46).jpg in dataset2
# no_tumor\Te-no_0050.jpg in dataset1 e no_tumor\image(50).jpg in dataset2
# no_tumor\Te-no_0050.jpg in dataset1 e no_tumor\image(54).jpg in dataset2
# no_tumor\Te-no_0051.jpg in dataset1 e no_tumor\image(51).jpg in dataset2
# no_tumor\Te-no_0052.jpg in dataset1 e no_tumor\image(41).jpg in dataset2
# no_tumor\Te-no_0052.jpg in dataset1 e no_tumor\image(52).jpg in dataset2
# no_tumor\Te-no_0053.jpg in dataset1 e no_tumor\image(15).jpg in dataset2
# no_tumor\Te-no_0053.jpg in dataset1 e no_tumor\image(49).jpg in dataset2
# no_tumor\Te-no_0053.jpg in dataset1 e no_tumor\image(53).jpg in dataset2
# no_tumor\Te-no_0053.jpg in dataset1 e no_tumor\image(67).jpg in dataset2
# no_tumor\Te-no_0053.jpg in dataset1 e no_tumor\image(84).jpg in dataset2
# no_tumor\Te-no_0054.jpg in dataset1 e no_tumor\image(46).jpg in dataset2
# no_tumor\Te-no_0054.jpg in dataset1 e no_tumor\image(50).jpg in dataset2
# no_tumor\Te-no_0054.jpg in dataset1 e no_tumor\image(54).jpg in dataset2
# no_tumor\Te-no_0055.jpg in dataset1 e no_tumor\image(16).jpg in dataset2
# no_tumor\Te-no_0055.jpg in dataset1 e no_tumor\image(45).jpg in dataset2
# no_tumor\Te-no_0055.jpg in dataset1 e no_tumor\image(55).jpg in dataset2
# no_tumor\Te-no_0055.jpg in dataset1 e no_tumor\image(60).jpg in dataset2
# no_tumor\Te-no_0056.jpg in dataset1 e no_tumor\image(56).jpg in dataset2
# no_tumor\Te-no_0057.jpg in dataset1 e no_tumor\image(57).jpg in dataset2
# no_tumor\Te-no_0058.jpg in dataset1 e no_tumor\image(58).jpg in dataset2
# no_tumor\Te-no_0059.jpg in dataset1 e no_tumor\image(59).jpg in dataset2
# no_tumor\Te-no_0060.jpg in dataset1 e no_tumor\image(47).jpg in dataset2
# no_tumor\Te-no_0060.jpg in dataset1 e no_tumor\image(6).jpg in dataset2
# no_tumor\Te-no_0061.jpg in dataset1 e no_tumor\image(16).jpg in dataset2
# no_tumor\Te-no_0061.jpg in dataset1 e no_tumor\image(45).jpg in dataset2
# no_tumor\Te-no_0061.jpg in dataset1 e no_tumor\image(55).jpg in dataset2
# no_tumor\Te-no_0061.jpg in dataset1 e no_tumor\image(60).jpg in dataset2
# no_tumor\Te-no_0062.jpg in dataset1 e no_tumor\image(22).jpg in dataset2
# no_tumor\Te-no_0062.jpg in dataset1 e no_tumor\image(61).jpg in dataset2
# no_tumor\Te-no_0062.jpg in dataset1 e no_tumor\image(71).jpg in dataset2
# no_tumor\Te-no_0063.jpg in dataset1 e no_tumor\image(62).jpg in dataset2
# no_tumor\Te-no_0064.jpg in dataset1 e no_tumor\image(63).jpg in dataset2
# no_tumor\Te-no_0065.jpg in dataset1 e no_tumor\image(32).jpg in dataset2
# no_tumor\Te-no_0065.jpg in dataset1 e no_tumor\image(64).jpg in dataset2
# no_tumor\Te-no_0066.jpg in dataset1 e no_tumor\image(65).jpg in dataset2
# no_tumor\Te-no_0067.jpg in dataset1 e no_tumor\image(10).jpg in dataset2
# no_tumor\Te-no_0067.jpg in dataset1 e no_tumor\image(33).jpg in dataset2
# no_tumor\Te-no_0067.jpg in dataset1 e no_tumor\image(66).jpg in dataset2
# no_tumor\Te-no_0067.jpg in dataset1 e no_tumor\image(81).jpg in dataset2
# no_tumor\Te-no_0068.jpg in dataset1 e no_tumor\image(15).jpg in dataset2
# no_tumor\Te-no_0068.jpg in dataset1 e no_tumor\image(49).jpg in dataset2
# no_tumor\Te-no_0068.jpg in dataset1 e no_tumor\image(53).jpg in dataset2
# no_tumor\Te-no_0068.jpg in dataset1 e no_tumor\image(67).jpg in dataset2
# no_tumor\Te-no_0068.jpg in dataset1 e no_tumor\image(84).jpg in dataset2
# no_tumor\Te-no_0069.jpg in dataset1 e no_tumor\image(31).jpg in dataset2
# no_tumor\Te-no_0069.jpg in dataset1 e no_tumor\image(68).jpg in dataset2
# no_tumor\Te-no_0070.jpg in dataset1 e no_tumor\image(21).jpg in dataset2
# no_tumor\Te-no_0070.jpg in dataset1 e no_tumor\image(69).jpg in dataset2
# no_tumor\Te-no_0071.jpg in dataset1 e no_tumor\image(7).jpg in dataset2
# no_tumor\Te-no_0072.jpg in dataset1 e no_tumor\image(24).jpg in dataset2
# no_tumor\Te-no_0072.jpg in dataset1 e no_tumor\image(70).jpg in dataset2
# no_tumor\Te-no_0073.jpg in dataset1 e no_tumor\image(22).jpg in dataset2
# no_tumor\Te-no_0073.jpg in dataset1 e no_tumor\image(61).jpg in dataset2
# no_tumor\Te-no_0073.jpg in dataset1 e no_tumor\image(71).jpg in dataset2
# no_tumor\Te-no_0074.jpg in dataset1 e no_tumor\image(72).jpg in dataset2
# no_tumor\Te-no_0075.jpg in dataset1 e no_tumor\image(25).jpg in dataset2
# no_tumor\Te-no_0075.jpg in dataset1 e no_tumor\image(73).jpg in dataset2
# no_tumor\Te-no_0076.jpg in dataset1 e no_tumor\image(74).jpg in dataset2
# no_tumor\Te-no_0077.jpg in dataset1 e no_tumor\image(48).jpg in dataset2
# no_tumor\Te-no_0077.jpg in dataset1 e no_tumor\image(75).jpg in dataset2
# no_tumor\Te-no_0078.jpg in dataset1 e no_tumor\image(76).jpg in dataset2
# no_tumor\Te-no_0079.jpg in dataset1 e no_tumor\image(77).jpg in dataset2
# no_tumor\Te-no_0080.jpg in dataset1 e no_tumor\image(78).jpg in dataset2
# no_tumor\Te-no_0081.jpg in dataset1 e no_tumor\image(37).jpg in dataset2
# no_tumor\Te-no_0081.jpg in dataset1 e no_tumor\image(79).jpg in dataset2
# no_tumor\Te-no_0082.jpg in dataset1 e no_tumor\image(8).jpg in dataset2
# no_tumor\Te-no_0083.jpg in dataset1 e no_tumor\image(80).jpg in dataset2
# no_tumor\Te-no_0083.jpg in dataset1 e no_tumor\image(9).jpg in dataset2
# no_tumor\Te-no_0084.jpg in dataset1 e no_tumor\image(10).jpg in dataset2
# no_tumor\Te-no_0084.jpg in dataset1 e no_tumor\image(33).jpg in dataset2
# no_tumor\Te-no_0084.jpg in dataset1 e no_tumor\image(66).jpg in dataset2
# no_tumor\Te-no_0084.jpg in dataset1 e no_tumor\image(81).jpg in dataset2
# no_tumor\Te-no_0085.jpg in dataset1 e no_tumor\image(82).jpg in dataset2
# no_tumor\Te-no_0086.jpg in dataset1 e no_tumor\image(83).jpg in dataset2
# no_tumor\Te-no_0087.jpg in dataset1 e no_tumor\image(15).jpg in dataset2
# no_tumor\Te-no_0087.jpg in dataset1 e no_tumor\image(49).jpg in dataset2
# no_tumor\Te-no_0087.jpg in dataset1 e no_tumor\image(53).jpg in dataset2
# no_tumor\Te-no_0087.jpg in dataset1 e no_tumor\image(67).jpg in dataset2
# no_tumor\Te-no_0087.jpg in dataset1 e no_tumor\image(84).jpg in dataset2
# no_tumor\Te-no_0088.jpg in dataset1 e no_tumor\image(11).jpg in dataset2
# no_tumor\Te-no_0088.jpg in dataset1 e no_tumor\image(85).jpg in dataset2
# no_tumor\Te-no_0089.jpg in dataset1 e no_tumor\image(86).jpg in dataset2
# no_tumor\Te-no_0090.jpg in dataset1 e no_tumor\image(87).jpg in dataset2
# no_tumor\Te-no_0091.jpg in dataset1 e no_tumor\image(88).jpg in dataset2
# no_tumor\Te-no_0092.jpg in dataset1 e no_tumor\image(89).jpg in dataset2
# no_tumor\Te-no_0093.jpg in dataset1 e no_tumor\image(80).jpg in dataset2
# no_tumor\Te-no_0093.jpg in dataset1 e no_tumor\image(9).jpg in dataset2
# no_tumor\Te-no_0094.jpg in dataset1 e no_tumor\image(90).jpg in dataset2
# no_tumor\Te-no_0095.jpg in dataset1 e no_tumor\image(91).jpg in dataset2
# no_tumor\Te-no_0096.jpg in dataset1 e no_tumor\image(92).jpg in dataset2
# no_tumor\Te-no_0097.jpg in dataset1 e no_tumor\image(93).jpg in dataset2
# no_tumor\Te-no_0098.jpg in dataset1 e no_tumor\image(94).jpg in dataset2
# no_tumor\Te-no_0099.jpg in dataset1 e no_tumor\image(95).jpg in dataset2
# no_tumor\Te-no_0100.jpg in dataset1 e no_tumor\image(96).jpg in dataset2
# no_tumor\Te-no_0101.jpg in dataset1 e no_tumor\image(97).jpg in dataset2
# no_tumor\Te-no_0102.jpg in dataset1 e no_tumor\image(98).jpg in dataset2
# no_tumor\Te-no_0103.jpg in dataset1 e no_tumor\image(99).jpg in dataset2
# no_tumor\Te-no_0104.jpg in dataset1 e no_tumor\image.jpg in dataset2
# no_tumor\Te-no_0215.jpg in dataset1 e no_tumor\image(78).jpg in dataset2

# %%
import os
import shutil
import imagehash
from PIL import Image

# Funzione per calcolare l'hash di tutte le immagini in una directory con sottocartelle
def calcola_hash(base_directory):
    hashes = {}
    for root, _, files in os.walk(base_directory):
        for filename in files:
            if filename.endswith((".png", ".jpg", ".jpeg")):
                image_path = os.path.join(root, filename)
                image = Image.open(image_path)
                image_hash = imagehash.phash(image)
                relative_path = os.path.relpath(image_path, base_directory)
                hashes[relative_path] = image_hash
    return hashes

# Percorsi dei dataset
dataset1_path = r""
dataset2_path = r""
dataset1_updated_path = r""

# Calcolare gli hash per i due dataset
hashes_dataset1 = calcola_hash(dataset1_path)
hashes_dataset2 = calcola_hash(dataset2_path)

# Confrontare gli hash e trovare immagini duplicate
immagini_duplicate = set()
for file1, hash1 in hashes_dataset1.items():
    for file2, hash2 in hashes_dataset2.items():
        if hash1 == hash2:
            immagini_duplicate.add(file1)

# Creare il nuovo dataset senza immagini duplicate
for root, _, files in os.walk(dataset1_path):
    for filename in files:
        if filename.endswith((".png", ".jpg", ".jpeg")):
            image_path = os.path.join(root, filename)
            relative_path = os.path.relpath(image_path, dataset1_path)
            new_image_path = os.path.join(dataset1_updated_path, relative_path)

            if relative_path not in immagini_duplicate:
                os.makedirs(os.path.dirname(new_image_path), exist_ok=True)
                shutil.copy2(image_path, new_image_path)

# Numero totale di immagini duplicate
numero_duplicati = len(immagini_duplicate)

# Stampa le immagini duplicate e il numero totale di immagini duplicate
print("Immagini duplicate rimosse dal dataset1:")
for img in immagini_duplicate:
    print(f"{img}")

print(f"\nNumero totale di immagini duplicate rimosse: {numero_duplicati}")
# Out:
# Immagini duplicate rimosse dal dataset1:
# meningioma_tumor\Te-me_0109.jpg
# meningioma_tumor\Te-meTr_0007.jpg
# meningioma_tumor\Te-me_0081.jpg
# meningioma_tumor\Te-me_0130.jpg
# glioma_tumor\Te-gl_0052.jpg
# meningioma_tumor\Te-me_0043.jpg
# pituitary_tumor\Te-pi_0064.jpg
# glioma_tumor\Te-glTr_0000.jpg
# pituitary_tumor\Te-pi_0022.jpg
# meningioma_tumor\Te-meTr_0001.jpg
# no_tumor\Te-no_0047.jpg
# glioma_tumor\Te-gl_0061.jpg
# meningioma_tumor\Te-me_0037.jpg
# no_tumor\Te-no_0225.jpg
# meningioma_tumor\Te-me_0094.jpg
# pituitary_tumor\Te-piTr_0007.jpg
# glioma_tumor\Te-gl_0048.jpg
# glioma_tumor\Te-gl_0013.jpg
# pituitary_tumor\Te-pi_0049.jpg
# no_tumor\Te-no_0039.jpg
# no_tumor\Te-no_0085.jpg
# glioma_tumor\Te-gl_0012.jpg
# meningioma_tumor\Te-me_0012.jpg
# pituitary_tumor\Te-piTr_0002.jpg
# pituitary_tumor\Te-pi_0050.jpg
# glioma_tumor\Te-gl_0036.jpg
# meningioma_tumor\Te-me_0040.jpg
# glioma_tumor\Te-gl_0066.jpg
# glioma_tumor\Te-gl_0039.jpg
# meningioma_tumor\Te-me_0115.jpg
# no_tumor\Te-no_0078.jpg
# no_tumor\Te-no_0203.jpg
# glioma_tumor\Te-gl_0021.jpg
# meningioma_tumor\Te-meTr_0008.jpg
# meningioma_tumor\Te-me_0113.jpg
# no_tumor\Te-no_0038.jpg
# pituitary_tumor\Te-pi_0052.jpg
# glioma_tumor\Te-gl_0029.jpg
# meningioma_tumor\Te-me_0119.jpg
# meningioma_tumor\Te-me_0083.jpg
# meningioma_tumor\Te-me_0069.jpg
# no_tumor\Te-no_0011.jpg
#
# Numero totale di immagini duplicate rimosse: 408

# %%
import os
import cv2
import shutil

def crop_to_content(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Threshold the image, then perform a series of erosions + dilations to remove any small regions of noise
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    c = max(cnts, key=cv2.contourArea)

    # Find the extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])

    # Apply crop
    ADD_PIXELS = 0
    new_image = image[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

    return new_image

def process_images(input_dir, output_dir):
    # Create output directories for each class if they don't exist
    class_folders = ["glioma_tumor", "meningioma_tumor", "no_tumor", "pituitary_tumor"]
    for folder in class_folders:
        os.makedirs(os.path.join(output_dir, folder), exist_ok=True)

    # Iterate through class folders
    for folder in class_folders:
        input_class_dir = os.path.join(input_dir, folder)
        output_class_dir = os.path.join(output_dir, folder)

        # Iterate through files in the class folder
        for filename in os.listdir(input_class_dir):
            if filename.endswith(".jpg") or filename.endswith(".png"):  # Adjust based on your file extensions
                input_path = os.path.join(input_class_dir, filename)
                output_path = os.path.join(output_class_dir, filename)

                # Read the image
                image = cv2.imread(input_path)
                if image is None:
                    continue  # Skip if image cannot be read

                # Process the image
                processed_image = crop_to_content(image)

                # Save processed image
                cv2.imwrite(output_path, processed_image)

                print(f"Processed: {os.path.join(folder, filename)}")

# Paths to input and output directories
input_directory = r""
output_directory = r""

# Process images
process_images(input_directory, output_directory)
# Out:
# Processed: glioma_tumor\image(1).jpg
# Processed: glioma_tumor\image(10).jpg
# Processed: glioma_tumor\image(100).jpg
# Processed: glioma_tumor\image(11).jpg
# Processed: glioma_tumor\image(12).jpg
# Processed: glioma_tumor\image(13).jpg
# Processed: glioma_tumor\image(14).jpg
# Processed: glioma_tumor\image(15).jpg
# Processed: glioma_tumor\image(16).jpg
# Processed: glioma_tumor\image(17).jpg
# Processed: glioma_tumor\image(18).jpg
# Processed: glioma_tumor\image(19).jpg
# Processed: glioma_tumor\image(2).jpg
# Processed: glioma_tumor\image(20).jpg
# Processed: glioma_tumor\image(21).jpg
# Processed: glioma_tumor\image(22).jpg
# Processed: glioma_tumor\image(23).jpg
# Processed: glioma_tumor\image(24).jpg
# Processed: glioma_tumor\image(25).jpg
# Processed: glioma_tumor\image(26).jpg
# Processed: glioma_tumor\image(27).jpg
# Processed: glioma_tumor\image(28).jpg
# Processed: glioma_tumor\image(29).jpg
# Processed: glioma_tumor\image(3).jpg
# Processed: glioma_tumor\image(30).jpg
# Processed: glioma_tumor\image(31).jpg
# Processed: glioma_tumor\image(32).jpg
# Processed: glioma_tumor\image(33).jpg
# Processed: glioma_tumor\image(34).jpg
# Processed: glioma_tumor\image(35).jpg
# Processed: glioma_tumor\image(36).jpg
# Processed: glioma_tumor\image(37).jpg
# Processed: glioma_tumor\image(38).jpg
# Processed: glioma_tumor\image(39).jpg
# Processed: glioma_tumor\image(4).jpg
# Processed: glioma_tumor\image(40).jpg
# Processed: glioma_tumor\image(41).jpg
# Processed: glioma_tumor\image(42).jpg
# Processed: glioma_tumor\image(43).jpg
# Processed: glioma_tumor\image(44).jpg
# Processed: glioma_tumor\image(45).jpg
# Processed: glioma_tumor\image(46).jpg
# Processed: glioma_tumor\image(47).jpg
# Processed: glioma_tumor\image(48).jpg
# Processed: glioma_tumor\image(49).jpg
# Processed: glioma_tumor\image(5).jpg
# Processed: glioma_tumor\image(50).jpg
# Processed: glioma_tumor\image(51).jpg
# Processed: glioma_tumor\image(52).jpg
# Processed: glioma_tumor\image(53).jpg
# Processed: glioma_tumor\image(54).jpg
# Processed: glioma_tumor\image(55).jpg
# Processed: glioma_tumor\image(56).jpg
# Processed: glioma_tumor\image(57).jpg
# Processed: glioma_tumor\image(58).jpg
# Processed: glioma_tumor\image(59).jpg
# Processed: glioma_tumor\image(6).jpg
# Processed: glioma_tumor\image(60).jpg
# Processed: glioma_tumor\image(61).jpg
# Processed: glioma_tumor\image(62).jpg
# Processed: glioma_tumor\image(63).jpg
# Processed: glioma_tumor\image(64).jpg
# Processed: glioma_tumor\image(65).jpg
# Processed: glioma_tumor\image(66).jpg
# Processed: glioma_tumor\image(67).jpg
# Processed: glioma_tumor\image(68).jpg
# Processed: glioma_tumor\image(69).jpg
# Processed: glioma_tumor\image(7).jpg
# Processed: glioma_tumor\image(70).jpg
# Processed: glioma_tumor\image(71).jpg
# Processed: glioma_tumor\image(72).jpg
# Processed: glioma_tumor\image(73).jpg
# Processed: glioma_tumor\image(74).jpg
# Processed: glioma_tumor\image(75).jpg
# Processed: glioma_tumor\image(76).jpg
# Processed: glioma_tumor\image(77).jpg
# Processed: glioma_tumor\image(78).jpg
# Processed: glioma_tumor\image(79).jpg
# Processed: glioma_tumor\image(8).jpg
# Processed: glioma_tumor\image(80).jpg
# Processed: glioma_tumor\image(81).jpg
# Processed: glioma_tumor\image(82).jpg
# Processed: glioma_tumor\image(83).jpg
# Processed: glioma_tumor\image(84).jpg
# Processed: glioma_tumor\image(85).jpg
# Processed: glioma_tumor\image(86).jpg
# Processed: glioma_tumor\image(87).jpg
# Processed: glioma_tumor\image(88).jpg
# Processed: glioma_tumor\image(89).jpg
# Processed: glioma_tumor\image(9).jpg
# Processed: glioma_tumor\image(90).jpg
# Processed: glioma_tumor\image(91).jpg
# Processed: glioma_tumor\image(92).jpg
# Processed: glioma_tumor\image(93).jpg
# Processed: glioma_tumor\image(94).jpg
# Processed: glioma_tumor\image(95).jpg
# Processed: glioma_tumor\image(97).jpg
# Processed: glioma_tumor\image(98).jpg
# Processed: glioma_tumor\image(99).jpg
# Processed: glioma_tumor\image.jpg
# Processed: meningioma_tumor\image(1).jpg
# Processed: meningioma_tumor\image(10).jpg
# Processed: meningioma_tumor\image(100).jpg
# Processed: meningioma_tumor\image(102).jpg
# Processed: meningioma_tumor\image(106).jpg
# Processed: meningioma_tumor\image(107).jpg
# Processed: meningioma_tumor\image(109).jpg
# Processed: meningioma_tumor\image(11).jpg
# Processed: meningioma_tumor\image(112).jpg
# Processed: meningioma_tumor\image(113).jpg
# Processed: meningioma_tumor\image(118).jpg
# Processed: meningioma_tumor\image(12).jpg
# Processed: meningioma_tumor\image(120).jpg
# Processed: meningioma_tumor\image(121).jpg
# Processed: meningioma_tumor\image(123).jpg
# Processed: meningioma_tumor\image(124).jpg
# Processed: meningioma_tumor\image(125).jpg
# Processed: meningioma_tumor\image(126).jpg
# Processed: meningioma_tumor\image(127).jpg
# Processed: meningioma_tumor\image(13).jpg
# Processed: meningioma_tumor\image(14).jpg
# Processed: meningioma_tumor\image(15).jpg
# Processed: meningioma_tumor\image(16).jpg
# Processed: meningioma_tumor\image(17).jpg
# Processed: meningioma_tumor\image(18).jpg
# Processed: meningioma_tumor\image(19).jpg
# Processed: meningioma_tumor\image(2).jpg
# Processed: meningioma_tumor\image(20).jpg
# Processed: meningioma_tumor\image(21).jpg
# Processed: meningioma_tumor\image(22).jpg
# Processed: meningioma_tumor\image(23).jpg
# Processed: meningioma_tumor\image(24).jpg
# Processed: meningioma_tumor\image(25).jpg
# Processed: meningioma_tumor\image(26).jpg
# Processed: meningioma_tumor\image(27).jpg
# Processed: meningioma_tumor\image(28).jpg
# Processed: meningioma_tumor\image(29).jpg
# Processed: meningioma_tumor\image(3).jpg
# Processed: meningioma_tumor\image(30).jpg
# Processed: meningioma_tumor\image(31).jpg
# Processed: meningioma_tumor\image(32).jpg
# Processed: meningioma_tumor\image(33).jpg
# Processed: meningioma_tumor\image(34).jpg
# Processed: meningioma_tumor\image(35).jpg
# Processed: meningioma_tumor\image(36).jpg
# Processed: meningioma_tumor\image(37).jpg
# Processed: meningioma_tumor\image(38).jpg
# Processed: meningioma_tumor\image(39).jpg
# Processed: meningioma_tumor\image(4).jpg
# Processed: meningioma_tumor\image(40).jpg
# Processed: meningioma_tumor\image(41).jpg
# Processed: meningioma_tumor\image(42).jpg
# Processed: meningioma_tumor\image(43).jpg
# Processed: meningioma_tumor\image(44).jpg
# Processed: meningioma_tumor\image(45).jpg
# Processed: meningioma_tumor\image(46).jpg
# Processed: meningioma_tumor\image(47).jpg
# Processed: meningioma_tumor\image(48).jpg
# Processed: meningioma_tumor\image(49).jpg
# Processed: meningioma_tumor\image(5).jpg
# Processed: meningioma_tumor\image(50).jpg
# Processed: meningioma_tumor\image(51).jpg
# Processed: meningioma_tumor\image(52).jpg
# Processed: meningioma_tumor\image(53).jpg
# Processed: meningioma_tumor\image(54).jpg
# Processed: meningioma_tumor\image(55).jpg
# Processed: meningioma_tumor\image(56).jpg
# Processed: meningioma_tumor\image(57).jpg
# Processed: meningioma_tumor\image(58).jpg
# Processed: meningioma_tumor\image(59).jpg
# Processed: meningioma_tumor\image(6).jpg
# Processed: meningioma_tumor\image(60).jpg
# Processed: meningioma_tumor\image(61).jpg
# Processed: meningioma_tumor\image(62).jpg
# Processed: meningioma_tumor\image(63).jpg
# Processed: meningioma_tumor\image(64).jpg
# Processed: meningioma_tumor\image(65).jpg
# Processed: meningioma_tumor\image(66).jpg
# Processed: meningioma_tumor\image(67).jpg
# Processed: meningioma_tumor\image(68).jpg
# Processed: meningioma_tumor\image(69).jpg
# Processed: meningioma_tumor\image(7).jpg
# Processed: meningioma_tumor\image(70).jpg
# Processed: meningioma_tumor\image(71).jpg
# Processed: meningioma_tumor\image(72).jpg
# Processed: meningioma_tumor\image(73).jpg
# Processed: meningioma_tumor\image(74).jpg
# Processed: meningioma_tumor\image(75).jpg
# Processed: meningioma_tumor\image(76).jpg
# Processed: meningioma_tumor\image(77).jpg
# Processed: meningioma_tumor\image(78).jpg
# Processed: meningioma_tumor\image(79).jpg
# Processed: meningioma_tumor\image(8).jpg
# Processed: meningioma_tumor\image(80).jpg
# Processed: meningioma_tumor\image(81).jpg
# Processed: meningioma_tumor\image(82).jpg
# Processed: meningioma_tumor\image(83).jpg
# Processed: meningioma_tumor\image(84).jpg
# Processed: meningioma_tumor\image(85).jpg
# Processed: meningioma_tumor\image(86).jpg
# Processed: meningioma_tumor\image(87).jpg
# Processed: meningioma_tumor\image(88).jpg
# Processed: meningioma_tumor\image(89).jpg
# Processed: meningioma_tumor\image(9).jpg
# Processed: meningioma_tumor\image(90).jpg
# Processed: meningioma_tumor\image(91).jpg
# Processed: meningioma_tumor\image(92).jpg
# Processed: meningioma_tumor\image(93).jpg
# Processed: meningioma_tumor\image(94).jpg
# Processed: meningioma_tumor\image(95).jpg
# Processed: meningioma_tumor\image(96).jpg
# Processed: meningioma_tumor\image(97).jpg
# Processed: meningioma_tumor\image(98).jpg
# Processed: meningioma_tumor\image(99).jpg
# Processed: meningioma_tumor\image.jpg
# Processed: no_tumor\image(1).jpg
# Processed: no_tumor\image(10).jpg
# Processed: no_tumor\image(100).jpg
# Processed: no_tumor\image(101).jpg
# Processed: no_tumor\image(102).jpg
# Processed: no_tumor\image(103).jpg
# Processed: no_tumor\image(104).jpg
# Processed: no_tumor\image(11).jpg
# Processed: no_tumor\image(12).jpg
# Processed: no_tumor\image(13).jpg
# Processed: no_tumor\image(14).jpg
# Processed: no_tumor\image(15).jpg
# Processed: no_tumor\image(16).jpg
# Processed: no_tumor\image(17).jpg
# Processed: no_tumor\image(18).jpg
# Processed: no_tumor\image(19).jpg
# Processed: no_tumor\image(2).jpg
# Processed: no_tumor\image(20).jpg
# Processed: no_tumor\image(21).jpg
# Processed: no_tumor\image(22).jpg
# Processed: no_tumor\image(23).jpg
# Processed: no_tumor\image(24).jpg
# Processed: no_tumor\image(25).jpg
# Processed: no_tumor\image(26).jpg
# Processed: no_tumor\image(27).jpg
# Processed: no_tumor\image(28).jpg
# Processed: no_tumor\image(29).jpg
# Processed: no_tumor\image(3).jpg
# Processed: no_tumor\image(30).jpg
# Processed: no_tumor\image(31).jpg
# Processed: no_tumor\image(32).jpg
# Processed: no_tumor\image(33).jpg
# Processed: no_tumor\image(34).jpg
# Processed: no_tumor\image(35).jpg
# Processed: no_tumor\image(36).jpg
# Processed: no_tumor\image(37).jpg
# Processed: no_tumor\image(38).jpg
# Processed: no_tumor\image(39).jpg
# Processed: no_tumor\image(4).jpg
# Processed: no_tumor\image(40).jpg
# Processed: no_tumor\image(41).jpg
# Processed: no_tumor\image(42).jpg
# Processed: no_tumor\image(43).jpg
# Processed: no_tumor\image(44).jpg
# Processed: no_tumor\image(45).jpg
# Processed: no_tumor\image(46).jpg
# Processed: no_tumor\image(47).jpg
# Processed: no_tumor\image(48).jpg
# Processed: no_tumor\image(49).jpg
# Processed: no_tumor\image(5).jpg
# Processed: no_tumor\image(50).jpg
# Processed: no_tumor\image(51).jpg
# Processed: no_tumor\image(52).jpg
# Processed: no_tumor\image(53).jpg
# Processed: no_tumor\image(54).jpg
# Processed: no_tumor\image(55).jpg
# Processed: no_tumor\image(56).jpg
# Processed: no_tumor\image(57).jpg
# Processed: no_tumor\image(58).jpg
# Processed: no_tumor\image(59).jpg
# Processed: no_tumor\image(6).jpg
# Processed: no_tumor\image(60).jpg
# Processed: no_tumor\image(61).jpg
# Processed: no_tumor\image(62).jpg
# Processed: no_tumor\image(63).jpg
# Processed: no_tumor\image(64).jpg
# Processed: no_tumor\image(65).jpg
# Processed: no_tumor\image(66).jpg
# Processed: no_tumor\image(67).jpg
# Processed: no_tumor\image(68).jpg
# Processed: no_tumor\image(69).jpg
# Processed: no_tumor\image(7).jpg
# Processed: no_tumor\image(70).jpg
# Processed: no_tumor\image(71).jpg
# Processed: no_tumor\image(72).jpg
# Processed: no_tumor\image(73).jpg
# Processed: no_tumor\image(74).jpg
# Processed: no_tumor\image(75).jpg
# Processed: no_tumor\image(76).jpg
# Processed: no_tumor\image(77).jpg
# Processed: no_tumor\image(78).jpg
# Processed: no_tumor\image(79).jpg
# Processed: no_tumor\image(8).jpg
# Processed: no_tumor\image(80).jpg
# Processed: no_tumor\image(81).jpg
# Processed: no_tumor\image(82).jpg
# Processed: no_tumor\image(83).jpg
# Processed: no_tumor\image(84).jpg
# Processed: no_tumor\image(85).jpg
# Processed: no_tumor\image(86).jpg
# Processed: no_tumor\image(87).jpg
# Processed: no_tumor\image(88).jpg
# Processed: no_tumor\image(89).jpg
# Processed: no_tumor\image(9).jpg
# Processed: no_tumor\image(90).jpg
# Processed: no_tumor\image(91).jpg
# Processed: no_tumor\image(92).jpg
# Processed: no_tumor\image(93).jpg
# Processed: no_tumor\image(94).jpg
# Processed: no_tumor\image(95).jpg
# Processed: no_tumor\image(96).jpg
# Processed: no_tumor\image(97).jpg
# Processed: no_tumor\image(98).jpg
# Processed: no_tumor\image(99).jpg
# Processed: no_tumor\image.jpg
# Processed: pituitary_tumor\image(1).jpg
# Processed: pituitary_tumor\image(10).jpg
# Processed: pituitary_tumor\image(11).jpg
# Processed: pituitary_tumor\image(13).jpg
# Processed: pituitary_tumor\image(15).jpg
# Processed: pituitary_tumor\image(18).jpg
# Processed: pituitary_tumor\image(19).jpg
# Processed: pituitary_tumor\image(2).jpg
# Processed: pituitary_tumor\image(20).jpg
# Processed: pituitary_tumor\image(21).jpg
# Processed: pituitary_tumor\image(22).jpg
# Processed: pituitary_tumor\image(23).jpg
# Processed: pituitary_tumor\image(27).jpg
# Processed: pituitary_tumor\image(28).jpg
# Processed: pituitary_tumor\image(3).jpg
# Processed: pituitary_tumor\image(30).jpg
# Processed: pituitary_tumor\image(31).jpg
# Processed: pituitary_tumor\image(34).jpg
# Processed: pituitary_tumor\image(35).jpg
# Processed: pituitary_tumor\image(36).jpg
# Processed: pituitary_tumor\image(37).jpg
# Processed: pituitary_tumor\image(38).jpg
# Processed: pituitary_tumor\image(41).jpg
# Processed: pituitary_tumor\image(42).jpg
# Processed: pituitary_tumor\image(43).jpg
# Processed: pituitary_tumor\image(44).jpg
# Processed: pituitary_tumor\image(45).jpg
# Processed: pituitary_tumor\image(46).jpg
# Processed: pituitary_tumor\image(47).jpg
# Processed: pituitary_tumor\image(48).jpg
# Processed: pituitary_tumor\image(49).jpg
# Processed: pituitary_tumor\image(5).jpg
# Processed: pituitary_tumor\image(51).jpg
# Processed: pituitary_tumor\image(52).jpg
# Processed: pituitary_tumor\image(53).jpg
# Processed: pituitary_tumor\image(54).jpg
# Processed: pituitary_tumor\image(55).jpg
# Processed: pituitary_tumor\image(56).jpg
# Processed: pituitary_tumor\image(57).jpg
# Processed: pituitary_tumor\image(6).jpg
# Processed: pituitary_tumor\image(60).jpg
# Processed: pituitary_tumor\image(61).jpg
# Processed: pituitary_tumor\image(63).jpg
# Processed: pituitary_tumor\image(64).jpg
# Processed: pituitary_tumor\image(65).jpg
# Processed: pituitary_tumor\image(66).jpg
# Processed: pituitary_tumor\image(67).jpg
# Processed: pituitary_tumor\image(68).jpg
# Processed: pituitary_tumor\image(69).jpg
# Processed: pituitary_tumor\image(7).jpg
# Processed: pituitary_tumor\image(70).jpg
# Processed: pituitary_tumor\image(73).jpg
# Processed: pituitary_tumor\image(76).jpg
# Processed: pituitary_tumor\image(77).jpg
# Processed: pituitary_tumor\image(78).jpg
# Processed: pituitary_tumor\image(79).jpg
# Processed: pituitary_tumor\image(8).jpg
# Processed: pituitary_tumor\image(81).jpg
# Processed: pituitary_tumor\image(82).jpg
# Processed: pituitary_tumor\image(85).jpg
# Processed: pituitary_tumor\image(86).jpg
# Processed: pituitary_tumor\image(87).jpg
# Processed: pituitary_tumor\image(88).jpg
# Processed: pituitary_tumor\image(89).jpg
# Processed: pituitary_tumor\image(90).jpg
# Processed: pituitary_tumor\image(91).jpg
# Processed: pituitary_tumor\image(92).jpg
# Processed: pituitary_tumor\image(93).jpg
# Processed: pituitary_tumor\image(94).jpg
# Processed: pituitary_tumor\image(95).jpg
# Processed: pituitary_tumor\image(96).jpg
# Processed: pituitary_tumor\image(97).jpg
# Processed: pituitary_tumor\image(98).jpg
# Processed: pituitary_tumor\image.jpg
